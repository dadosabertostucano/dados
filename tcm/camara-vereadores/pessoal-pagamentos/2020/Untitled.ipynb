# %%
import pandas as pd 

df = pd.read_csv('set-2020.csv')
df.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156             Agente Político
# 2  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 3         BELMIRO FERREIRA DA SILVA        172             Agente Político
# 4               BRUNO GAMA MEIRELES        197          Cargo Comissionado
#
#                  Cargo  Salário Base Salário Vantagens Salário Gratificação  \
# 0  POLICIA LEGISLATIVA   R$ 1.100,00         R$ 275,00              R$ 0,00
# 1             VEREADOR  R$ 10.128,89           R$ 0,00              R$ 0,00
# 2        RECEPCIONISTA   R$ 1.045,00         R$ 252,25              R$ 0,00
# 3             VEREADOR  R$ 10.128,89           R$ 0,00              R$ 0,00
# 4  CHEFE DE TRANSPORTE   R$ 1.200,00           R$ 0,00              R$ 0,00
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# ...
